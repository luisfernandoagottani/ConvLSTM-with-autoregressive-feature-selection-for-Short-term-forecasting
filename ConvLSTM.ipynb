# %%
import pandas as pd
import numpy as np
import datetime as dt

# My packages
from packages.thesis_sequence_algorithm_nominmax import thesis_sequence_algorithm
from packages.thesis_model_nominmax import evaluate_model

# Visualization
import matplotlib.pyplot as plt
import time
from dateutil.relativedelta import relativedelta

# %%
dataset = pd.read_csv('dataset_final_min.csv', infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
dataset_h = pd.read_csv('dataset_final.csv', infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])

# %% [markdown]
# # Thesis Model

# %% [markdown]
# - Prepare warm up period (Define quantity)
# - Train the ConvLSTM Model by warm-up period initially
# - Prepare previous hourly step (Define Quantity)
# - Select optimal correlated leg load by the Power Spectrum
# - If Correlated leg > Theta
#     - Update and reshape the input vector for ConvLSTM model
#     - Implement single step ahead forecast
#     - Retrain the ConvLSTM model by the observed hourly load of previous predicted time step
# - Else
#     - Implement persistence model
#     - Retrain the ConvLSTM model by the observed hourly load of previous predicted time step

# %%
dataset = dataset.loc[:,['Global_active_power','tempC','weekday','time']]
df_min = dataset[(dataset.index >= '2009-04-01') & (dataset.index < '2009-05-01')]
df_30 = df_min.resample('30min').mean()

# %%
list_theta = ['ConvLSTM']
for i in list_theta:
        start_date = '2009-04-01'
        end_date = '2009-05-01'
        dataset_filtered = df_30[(df_30.index >= start_date) & (df_30.index < end_date)]
        autocorrelation_type = 'ConvLSTM'
        algorithm = 'ConvLSTM 30min'
        warm_up_time = 336
        theta_threshold = i
        leg_days_time = 336
        n_steps = 1
        n_length = 1
        n_input = n_steps * n_length
        n_features = dataset_filtered.shape[1]
        n_out = 1
        epochs = 20
        epochs_retrain = 1
        batch_size = 1
        filters = 36
        activation = 'relu'
        loss = 'mse'
        optimizer = 'adam'
        karnel = (1,2)
        dense_1 = 4
        dense_2 = 1
        model_parameters_PSConvLSTM = thesis_sequence_algorithm(dataset_filtered, 
                                                                        autocorrelation_type, 
                                                                        warm_up_time, 
                                                                        theta_threshold, 
                                                                        leg_days_time, 
                                                                        n_steps, 
                                                                        n_length, 
                                                                        n_input, 
                                                                        n_features, 
                                                                        n_out, 
                                                                        epochs, 
                                                                        batch_size, 
                                                                        filters, 
                                                                        activation, 
                                                                        loss, 
                                                                        optimizer,
                                                                        karnel,
                                                                        epochs_retrain,
                                                                        dense_1,
                                                                        dense_2)
        #RUN ALGO
        start_time = time.time()
        predict_list_PSConvLSTM, observed_list_PSConvLSTM = model_parameters_PSConvLSTM.master_algorithm_convlstm()
        scores_PSConvLSTM = evaluate_model(predict_list_PSConvLSTM, observed_list_PSConvLSTM)
        score_PSConvLSTM, scores_PSConvLSTM = scores_PSConvLSTM.evaluate_model()
        time_run = (time.time() - start_time)
        # Read results csv
        teste = pd.read_csv('params_test.csv', index_col= 'Unnamed: 0')
        # Register actual version
        resgister_version = {'start_date': start_date, 'end_date': end_date, 'warm_up_time': warm_up_time, 'leg_days' : leg_days_time,
                            'theta_threshold': theta_threshold, 'leg_days_time': leg_days_time ,'n_length': n_length, 'epochs':epochs, 'filters':filters, 
                            'epochs_retrain': epochs_retrain, 'dense_1': dense_1, 'karnels' : [karnel], 
                            'score': score_PSConvLSTM, 'max_loss': np.max(scores_PSConvLSTM), 'time_run': time_run}
        # Create Data Frame
        resgister_version_df = pd.DataFrame(data = resgister_version, index = [algorithm] )
        # Concat and save
        pd.concat([teste, resgister_version_df]).to_csv('params_test.csv')
# Out:
# 14.345156908035278
# 109.98995971679688

# %%
scores_persistence = evaluate_model(df_30['Global_active_power'][335:-1], df_30['Global_active_power'][336:])
score_persistence, scores_persistence_s = scores_persistence.evaluate_model()
score_persistence
# Out:
# 0.5534433955985042

# %%
np.array(scores_persistence_s).max()
# Out:
# 4.1806

# %%
for i in range(0,10):    
    list_theta = [0.52, 0.56, 0.60, 0.64, 0.68]
    for i in list_theta:
            start_date = df.index[0]
            end_date = start_date + relativedelta(months = 1)
            while end_date < df.index[-1]:
                start_date = pd.to_datetime(start_date) + relativedelta(months = 1)
                end_date = pd.to_datetime(start_date) + relativedelta(months = 1)
                dataset_filtered = df[(df.index >= start_date) & (df.index < end_date)]
                autocorrelation_type = 'acf'
                algorithm = 'ConvLSTM (Adapted with autoregressive lag being t-1 and higher length)'
                warm_up_time = 168
                theta_threshold = i
                leg_days_time = 168
                n_steps = 1
                n_length = 24
                n_input = n_steps * n_length
                n_features = df.shape[1]
                n_out = 1
                epochs = 20
                epochs_retrain = 1
                batch_size = 1
                filters = 36
                activation = 'relu'
                loss = 'mse'
                optimizer = 'adam'
                karnel = (1,2)
                dense_1 = 4
                dense_2 = 1
                model_parameters_PSConvLSTM = thesis_sequence_algorithm(dataset_filtered, 
                                                                        autocorrelation_type, 
                                                                        warm_up_time, 
                                                                        theta_threshold, 
                                                                        leg_days_time, 
                                                                        n_steps, 
                                                                        n_length, 
                                                                        n_input, 
                                                                        n_features, 
                                                                        n_out, 
                                                                        epochs, 
                                                                        batch_size, 
                                                                        filters, 
                                                                        activation, 
                                                                        loss, 
                                                                        optimizer,
                                                                        karnel,
                                                                        epochs_retrain,
                                                                        dense_1,
                                                                        dense_2)
                #RUN ALGO
                start_time = time.time()
                predict_list_PSConvLSTM, observed_list_PSConvLSTM = model_parameters_PSConvLSTM.master_algorithm_convlstm()
                scores_PSConvLSTM = evaluate_model(predict_list_PSConvLSTM, observed_list_PSConvLSTM)
                score_PSConvLSTM, scores_PSConvLSTM = scores_PSConvLSTM.evaluate_model()
                time_run = (time.time() - start_time)
                # Read results csv
                teste = pd.read_csv('params_test.csv', index_col= 'Unnamed: 0')
                # Register actual version
                resgister_version = {'start_date': start_date, 'end_date': end_date, 'warm_up_time': warm_up_time, 'leg_days' : leg_days_time,
                                    'theta_threshold': theta_threshold, 'leg_days_time': leg_days_time ,'n_length': n_length, 'epochs':epochs, 'filters':filters, 
                                    'epochs_retrain': epochs_retrain, 'dense_1': dense_1, 'karnels' : [karnel], 
                                    'score': score_PSConvLSTM, 'max_loss': np.max(scores_PSConvLSTM), 'time_run': time_run}
                # Create Data Frame
                resgister_version_df = pd.DataFrame(data = resgister_version, index = [algorithm] )
# 25.943700790405273
# 4.973825216293335
# 21.258483171463013
# 4.76174259185791
# 21.061671018600464
# 4.801315784454346
# 22.860581159591675
# 4.756280899047852
# 39.675321102142334
# 5.086143732070923
# 40.75695490837097
# 4.946476221084595
# 39.417816162109375
# 5.290302276611328
# 41.074871301651
# 5.1193952560424805
# 40.71725034713745
# 5.080029010772705
# 35.765312910079956
# 4.849122524261475
# 40.833889961242676
# 4.769042730331421
# 39.31597661972046
# 4.830384016036987
# 40.33268880844116
# 4.669087886810303
# 38.161158323287964
# 4.833073854446411
# 31.245243787765503
# 4.8316428661346436
# 35.79878067970276
# 4.74738621711731
# 39.28300213813782
# 4.9788734912872314
# 41.06931138038635
# 4.976308822631836
# 39.04848003387451
# 4.845753908157349
# 40.59349489212036
# 4.779922723770142
# 40.20408868789673
# 5.044468402862549
# 35.582104444503784
# 4.90132212638855
# 41.151997804641724
# 5.151329755783081
# 39.57115721702576
# 4.9063639640808105
# 40.857234716415405
# 4.788414716720581
# 38.66255831718445
# 4.926806926727295
# 33.75178408622742
# 4.828808546066284
# 35.19748306274414
# 4.880148887634277
# 41.05774927139282
# 4.788984775543213
# 38.88267922401428
# 5.043826580047607
# 41.35317945480347
# 4.671464204788208
# 40.58380341529846
# 4.868103742599487
# 35.666425943374634
# 5.08095645904541
# 39.557647466659546
# 4.77689266204834
# 39.12565088272095
# 5.122866630554199
# 37.4107449054718
# 4.867385149002075
# 33.05701756477356
# 4.819638729095459
# 27.36251473426819
# 4.903159141540527
# 33.18880605697632
# 5.117257118225098
# 39.17790365219116
# 4.849516153335571
# 40.665624380111694
# 4.824735879898071
# 39.170154333114624
# 4.804542779922485
# 41.01794910430908
# 4.6261818408966064
# 41.157204389572144
# 4.773569583892822
# 36.229411602020264
# 4.857917070388794
# 40.621673822402954
# 5.367602825164795
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\agottanil\Downloads\Agottani\Thesis\ConvLSTM.ipynb Cell 7 in <cell line: 1>()
#      <a href='vscode-notebook-cell:/c%3A/Users/agottanil/Downloads/Agottani/Thesis/ConvLSTM.ipynb#W6sZmlsZQ%3D%3D?line=49'>50</a> #RUN ALGO
#      <a href='vscode-notebook-cell:/c%3A/Users/agottanil/Downloads/Agottani/Thesis/ConvLSTM.ipynb#W6sZmlsZQ%3D%3D?line=50'>51</a> start_time = time.time()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/agottanil/Downloads/Agottani/Thesis/ConvLSTM.ipynb#W6sZmlsZQ%3D%3D?line=51'>52</a> predict_list_PSConvLSTM, observed_list_PSConvLSTM = model_parameters_PSConvLSTM.master_algorithm()
#      <a href='vscode-notebook-cell:/c%3A/Users/agottanil/Downloads/Agottani/Thesis/ConvLSTM.ipynb#W6sZmlsZQ%3D%3D?line=52'>53</a> scores_PSConvLSTM = evaluate_model(predict_list_PSConvLSTM, observed_list_PSConvLSTM)
#      <a href='vscode-notebook-cell:/c%3A/Users/agottanil/Downloads/Agottani/Thesis/ConvLSTM.ipynb#W6sZmlsZQ%3D%3D?line=53'>54</a> score_PSConvLSTM, scores_PSConvLSTM = scores_PSConvLSTM.evaluate_model()
#
# File c:\Users\agottanil\Downloads\Agottani\Thesis\packages\thesis_sequence_algorithm_nominmax.py:120, in thesis_sequence_algorithm.master_algorithm(self)
#     118 input_x = input_x.reshape((1, self.n_steps, self.n_length, self.n_features,1))
#     119 # Implement single step ahead forecast by the ConvLSTM model
# --> 120 y_hat = model.predict(input_x, verbose=0)
#     121 # Append predicted load for model evaluation
#     122 predict_list.append(y_hat[0][0])
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:1951, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1944   except ValueError:
#    1945     warnings.warn(
#    1946         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    1947         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1948         'result. Consider setting it to AutoShardPolicy.DATA.',
#    1949         stacklevel=2)
# -> 1951 data_handler = data_adapter.get_data_handler(
#    1952     x=x,
#    1953     batch_size=batch_size,
#    1954     steps_per_epoch=steps,
#    1955     initial_epoch=0,
#    1956     epochs=1,
#    1957     max_queue_size=max_queue_size,
#    1958     workers=workers,
#    1959     use_multiprocessing=use_multiprocessing,
#    1960     model=self,
#    1961     steps_per_execution=self._steps_per_execution)
#    1963 # Container that configures and calls `tf.keras.Callback`s.
#    1964 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1399, in get_data_handler(*args, **kwargs)
#    1397 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399 return DataHandler(*args, **kwargs)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution = steps_per_execution
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=tf.distribute.get_strategy(),
#    1161     model=model)
#    1163 strategy = tf.distribute.get_strategy()
#    1165 self._current_step = 0
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:328, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     324   return flat_dataset
#     326 indices_dataset = indices_dataset.flat_map(slice_batch_indices)
# --> 328 dataset = self.slice_inputs(indices_dataset, inputs)
#     330 if shuffle == "batch":
#     331   def shuffle_batch(*batch):
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\data_adapter.py:360, in TensorLikeDataAdapter.slice_inputs(self, indices_dataset, inputs)
#     357 def grab_batch(i, data):
#     358   return tf.nest.map_structure(lambda d: tf.gather(d, i, axis=0), data)
# --> 360 dataset = dataset.map(
#     361     grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     363 # Default optimizations are disabled to avoid the overhead of (unnecessary)
#     364 # input pipeline graph serialization and deserialization
#     365 options = tf.data.Options()
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2018, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2016   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2017 else:
# -> 2018   return ParallelMapDataset(
#    2019       self,
#    2020       map_func,
#    2021       num_parallel_calls,
#    2022       deterministic,
#    2023       preserve_cardinality=True,
#    2024       name=name)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:5234, in ParallelMapDataset.__init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5232 self._input_dataset = input_dataset
#    5233 self._use_inter_op_parallelism = use_inter_op_parallelism
# -> 5234 self._map_func = structured_function.StructuredFunctionWrapper(
#    5235     map_func,
#    5236     self._transformation_name(),
#    5237     dataset=input_dataset,
#    5238     use_legacy_function=use_legacy_function)
#    5239 if deterministic is None:
#    5240   self._deterministic = "default"
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     264       warnings.warn(
#     265           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     266           "option is set, this option does not apply to tf.data functions. "
#     267           "To force eager execution of tf.data functions, please use "
#     268           "`tf.data.experimental.enable_debug_mode()`.")
#     269     fn_factory = trace_tf_function(defun_kwargs)
# --> 271 self._function = fn_factory()
#     272 # There is no graph to add in eager mode.
#     273 add_to_graph &= not context.executing_eagerly()
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:3070, in Function.get_concrete_function(self, *args, **kwargs)
#    3061 def get_concrete_function(self, *args, **kwargs):
#    3062   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    3063
#    3064   Args:
#    (...)
#    3068        or `tf.Tensor` or `tf.TensorSpec`.
#    3069   """
# -> 3070   graph_function = self._get_concrete_function_garbage_collected(
#    3071       *args, **kwargs)
#    3072   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3073   return graph_function
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:3036, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034   args, kwargs = None, None
#    3035 with self._lock:
# -> 3036   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037   seen_names = set()
#    3038   captured = object_identity.ObjectIdentitySet(
#    3039       graph_function.graph.internal_captures)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1075, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1073   arg_shapes = None
#    1074   kwarg_shapes = None
# -> 1075 func_args = _get_defun_inputs_from_args(
#    1076     args, arg_names, flat_shapes=arg_shapes)
#    1077 func_kwargs = _get_defun_inputs_from_kwargs(
#    1078     kwargs, flat_shapes=kwarg_shapes)
#    1080 # Convert all Tensors into TensorSpecs before saving the structured inputs.
#    1081 # If storing pure concrete functions that are not called through polymorphic
#    1082 # functions, we don't have access to FunctionSpec, so we need to call the
#    1083 # TensorSpecs by their `arg_names` for later binding.
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1313, in _get_defun_inputs_from_args(args, names, flat_shapes)
#    1311 def _get_defun_inputs_from_args(args, names, flat_shapes=None):
#    1312   """Maps Python function positional args to graph-construction inputs."""
# -> 1313   return _get_defun_inputs(
#    1314       args, names, structure=args, flat_shapes=flat_shapes)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:1386, in _get_defun_inputs(args, names, structure, flat_shapes)
#    1384 placeholder_shape = shape if shape is not None else arg.shape
#    1385 try:
# -> 1386   placeholder = graph_placeholder(
#    1387       arg.dtype, placeholder_shape,
#    1388       name=requested_name)
#    1389 except ValueError:
#    1390   # Sometimes parameter names are not valid op names, so fall back to
#    1391   # unnamed placeholders.
#    1392   placeholder = graph_placeholder(arg.dtype, placeholder_shape)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\graph_only_ops.py:34, in graph_placeholder(dtype, shape, name)
#      32 g = ops.get_default_graph()
#      33 attrs = {"dtype": dtype_value, "shape": shape}
# ---> 34 op = g._create_op_internal(  # pylint: disable=protected-access
#      35     "Placeholder", [], [dtype], input_types=[],
#      36     attrs=attrs, name=name)
#      37 result, = op.outputs
#      38 if op_callbacks.should_invoke_op_callbacks():
#      39   # TODO(b/147670703): Once the special-op creation code paths
#      40   # are unified. Remove this `if` block.
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\func_graph.py:693, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     691   inp = self.capture(inp)
#     692   captured_inputs.append(inp)
# --> 693 return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     694     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     695     compute_device)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:3776, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3773 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    3774 # Session.run call cannot occur between creating and mutating the op.
#    3775 with self._mutation_lock():
# -> 3776   ret = Operation(
#    3777       node_def,
#    3778       self,
#    3779       inputs=inputs,
#    3780       output_types=dtypes,
#    3781       control_inputs=control_inputs,
#    3782       input_types=input_types,
#    3783       original_op=self._default_original_op,
#    3784       op_def=op_def)
#    3785   self._create_op_helper(ret, compute_device=compute_device)
#    3786 return ret
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:2171, in Operation.__init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2169   if op_def is None:
#    2170     op_def = self._graph._get_op_def(node_def.op)
# -> 2171   self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2172                             control_input_ops, op_def)
#    2173   name = compat.as_str(node_def.name)
#    2175 self._traceback = tf_stack.extract_stack_for_node(self._c_op)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\agottanil\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\framework\ops.py:2010, in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    2006   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    2007                                          serialized)
#    2009 try:
# -> 2010   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    2011 except errors.InvalidArgumentError as e:
#    2012   # Convert to ValueError for backwards compatibility.
#    2013   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %% [markdown]
# # Minute Step

# %%
dataset = dataset.loc[:,['Global_active_power','Sub_metering_1','Sub_metering_2','Sub_metering_3','tempC','weekday','time']]
df_min = dataset[(dataset.index >= '2008-08-01') & (dataset.index < '2010-08-01')]
df_min
# Out:
#                      Global_active_power  Sub_metering_1  Sub_metering_2  \
# datetime
# 2008-08-01 00:00:00                0.500             0.0            0.00
# 2008-08-01 00:01:00                0.482             0.0            0.00
# 2008-08-01 00:02:00                0.502             0.0            0.00
# 2008-08-01 00:03:00                0.556             0.0            0.00
# 2008-08-01 00:04:00                0.854             0.0            0.06
# ...                                  ...             ...             ...
# 2010-07-31 23:55:00                0.152             0.0            0.00
# 2010-07-31 23:56:00                0.152             0.0            0.00
# 2010-07-31 23:57:00                0.152             0.0            0.00
# 2010-07-31 23:58:00                0.154             0.0            0.00
# 2010-07-31 23:59:00                0.152             0.0            0.00
#
#                      Sub_metering_3  tempC  weekday  time
# datetime
# 2008-08-01 00:00:00            0.06     20        0     0
# 2008-08-01 00:01:00            0.06     20        0     0
# 2008-08-01 00:02:00            0.00     20        0     0
# 2008-08-01 00:03:00            0.06     20        0     0
# 2008-08-01 00:04:00            0.42     20        0     0
# ...                             ...    ...      ...   ...
# 2010-07-31 23:55:00            0.06     18        1    23
# 2010-07-31 23:56:00            0.00     18        1    23
# 2010-07-31 23:57:00            0.06     18        1    23
# 2010-07-31 23:58:00            0.00     18        1    23
# 2010-07-31 23:59:00            0.06     17        1     0
#
# [1051200 rows x 7 columns]

# %%
list_theta = [500,500]
for i in list_theta:
        start_date = '2009-02-01'
        end_date = '2009-03-01'
        dataset_filtered = df_min[(df_min.index >= start_date) & (df_min.index < end_date)]
        autocorrelation_type = 'ConvLSTM'
        warm_up_time = 10080
        theta_threshold = i
        leg_days_time = 10080
        n_steps = 1
        n_length = 1
        n_input = n_steps * n_length
        n_features = df_min.shape[1]
        n_out = 1
        epochs = 20
        epochs_retrain = 1
        batch_size = 1
        filters = 36
        activation = 'relu'
        loss = 'mse'
        optimizer = 'adam'
        karnel = (1,2)
        dense_1 = 4
        dense_2 = 1
        model_parameters_PSConvLSTM = thesis_sequence_algorithm(dataset_filtered, 
                                                                autocorrelation_type, 
                                                                warm_up_time, 
                                                                theta_threshold, 
                                                                leg_days_time, 
                                                                n_steps, 
                                                                n_length, 
                                                                n_input, 
                                                                n_features, 
                                                                n_out, 
                                                                epochs, 
                                                                batch_size, 
                                                                filters, 
                                                                activation, 
                                                                loss, 
                                                                optimizer,
                                                                karnel,
                                                                epochs_retrain,
                                                                dense_1,
                                                                dense_2)
        #RUN ALGO
        start_time = time.time()
        predict_list_PSConvLSTM, observed_list_PSConvLSTM = model_parameters_PSConvLSTM.master_algorithm_convlstm()
        scores_PSConvLSTM = evaluate_model(predict_list_PSConvLSTM, observed_list_PSConvLSTM)
        score_PSConvLSTM, scores_PSConvLSTM = scores_PSConvLSTM.evaluate_model()
        time_run = (time.time() - start_time)
        # Read results csv
        teste = pd.read_csv('params_test.csv', index_col= 'Unnamed: 0')
        # Register actual version
        resgister_version = {'start_date': start_date, 'end_date': end_date, 'warm_up_time': warm_up_time, 'leg_days' : leg_days_time,
                            'theta_threshold': theta_threshold, 'leg_days_time': leg_days_time ,'n_length': n_length, 'epochs':epochs, 'filters':filters, 
                            'epochs_retrain': epochs_retrain, 'dense_1': dense_1, 'karnels' : [karnel], 
                            'score': score_PSConvLSTM, 'max_loss': np.max(scores_PSConvLSTM), 'time_run': time_run}
        # Create Data Frame
        resgister_version_df = pd.DataFrame(data = resgister_version, index = [pd.to_datetime(dt.datetime.today())] )
        # Concat and save
        pd.concat([teste, resgister_version_df]).to_csv('params_test.csv')
